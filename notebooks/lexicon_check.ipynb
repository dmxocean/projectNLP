# %% [markdown]
# ### Lexicon Check

# %%
import os
import sys

sys.path.append('..')

from utils.lexicon import *

# %%
negation_test_words = ["no", "sin", "negativo", "afebril", "niega"]

print("Testing negation terms:\n")

for word in negation_test_words:
    result = is_negation(word)
    print(f"'{word}' negation term: {result}")

# %%
uncertainty_test_words = ["probable", "posible", "compatible con", "sospecha de", "probablemente"]

print("Testing uncertainty terms:\n")
for word in uncertainty_test_words:
    result = is_uncertainty(word)
    print(f"'{word}' uncertainty term: {result}")

# %%
# TODO Modify lexicon_builder to handle multiple languages

# Get term counts for each language
print(f"Spanish negation term count: {len(get_all_negation('es'))}")
print(f"Catalan negation term count: {len(get_all_negation('ca'))}")
print(f"All negation term count: {len(get_all_negation('ALL'))}")
print()

print(f"Spanish uncertainty term count: {len(get_all_uncertainty('es'))}")
print(f"Catalan uncertainty term count: {len(get_all_uncertainty('ca'))}")
print(f"All uncertainty term count: {len(get_all_uncertainty('ALL'))}")

# %%
print(f"'NO' a negation term: {is_negation('NO')}")
print(f"'No' a negation term: {is_negation('No')}")
print(f"'no' a negation term: {is_negation('no')}")

print(f"'PROBABLE' an uncertainty term: {is_uncertainty('PROBABLE')}")
print(f"'Probable' an uncertainty term: {is_uncertainty('Probable')}")
print(f"'probable' an uncertainty term: {is_uncertainty('probable')}")

# %%
negation_terms = get_all_negation()

print("Top negation terms:")
for term in negation_terms[:20]:
    print(f"  {term}")

# %%
uncertainty_terms = get_all_uncertainty()

print("Top uncertainty terms:")
for term in uncertainty_terms[:20]:
    print(f"  {term}")
